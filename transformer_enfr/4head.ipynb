# %% [markdown]
# #### 4头

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 4 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --use_multihead --use_positional_encoding --use_residual --use_layernorm --use_decoder --experiment_name=4_heads
# Out:
# 训练结果将保存在: results_ablation/4_heads_20251105_033423
# 使用设备: cuda
#
# 消融实验设置:
# 多头注意力: 启用
# 位置编码: 启用
# 残差连接: 启用
# LayerNorm: 启用
# 解码器: 启用
#
# 构建数据集...
#
# 创建模型...
# 模型参数量: 19,333,664
#
# 开始训练...
# Epoch 1/30: 100%|███████████████| 1589/1589 [02:19<00:00, 11.39it/s, loss=4.080]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:11,  1.49it/s]
# Epoch 1: train loss 5.4692 | val loss 4.3040 | val BLEU 6.64%
#   保存新的最佳模型: val bleu = 6.64%
# Epoch 2/30: 100%|███████████████| 1589/1589 [02:20<00:00, 11.35it/s, loss=3.785]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:13,  1.46it/s]
# Epoch 2: train loss 3.9644 | val loss 3.5138 | val BLEU 10.74%
#   保存新的最佳模型: val bleu = 10.74%
# Epoch 3/30: 100%|███████████████| 1589/1589 [02:20<00:00, 11.34it/s, loss=3.176]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:15,  1.45it/s]
# Epoch 3: train loss 3.3475 | val loss 3.1189 | val BLEU 14.58%
#   保存新的最佳模型: val bleu = 14.58%
# Epoch 4/30: 100%|███████████████| 1589/1589 [02:19<00:00, 11.36it/s, loss=3.562]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:04,  1.58it/s]
# Epoch 4: train loss 2.9569 | val loss 2.8566 | val BLEU 17.10%
#   保存新的最佳模型: val bleu = 17.10%
# Epoch 5/30: 100%|███████████████| 1589/1589 [02:19<00:00, 11.37it/s, loss=2.475]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:12,  1.48it/s]
# Epoch 5: train loss 2.6673 | val loss 2.7266 | val BLEU 17.74%
#   保存新的最佳模型: val bleu = 17.74%
# Epoch 6/30: 100%|███████████████| 1589/1589 [02:19<00:00, 11.39it/s, loss=2.569]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:07,  1.54it/s]
# Epoch 6: train loss 2.4705 | val loss 2.6474 | val BLEU 18.52%
#   保存新的最佳模型: val bleu = 18.52%
# Epoch 7/30: 100%|███████████████| 1589/1589 [02:21<00:00, 11.26it/s, loss=2.127]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:11,  1.49it/s]
# Epoch 7: train loss 2.3194 | val loss 2.5971 | val BLEU 21.05%
#   保存新的最佳模型: val bleu = 21.05%
# Epoch 8/30: 100%|███████████████| 1589/1589 [02:21<00:00, 11.24it/s, loss=2.029]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:01,  1.61it/s]
# Epoch 8: train loss 2.1972 | val loss 2.5448 | val BLEU 20.37%
# Epoch 9/30: 100%|███████████████| 1589/1589 [02:20<00:00, 11.31it/s, loss=1.933]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:23,  1.37it/s]
# Epoch 9: train loss 2.0912 | val loss 2.5157 | val BLEU 19.92%
# Epoch 10/30: 100%|██████████████| 1589/1589 [02:21<00:00, 11.20it/s, loss=1.962]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:21,  1.39it/s]
# Epoch 10: train loss 2.0007 | val loss 2.4957 | val BLEU 21.16%
#   保存新的最佳模型: val bleu = 21.16%
# Epoch 11/30: 100%|██████████████| 1589/1589 [02:20<00:00, 11.34it/s, loss=1.979]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:08,  1.53it/s]
# Epoch 11: train loss 1.9193 | val loss 2.4994 | val BLEU 22.13%
#   保存新的最佳模型: val bleu = 22.13%
# Epoch 12/30: 100%|██████████████| 1589/1589 [02:20<00:00, 11.34it/s, loss=1.785]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:58,  1.66it/s]
# Epoch 12: train loss 1.8448 | val loss 2.4972 | val BLEU 22.50%
#   保存新的最佳模型: val bleu = 22.50%
# Epoch 13/30:   1%|▏               | 16/1589 [00:01<02:25, 10.81it/s, loss=1.684]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Epoch 24/30: 100%|██████████████| 1589/1589 [02:20<00:00, 11.30it/s, loss=1.246]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:20,  1.39it/s]
# Epoch 24: train loss 1.2414 | val loss 2.6682 | val BLEU 23.32%
# Epoch 25/30: 100%|██████████████| 1589/1589 [02:20<00:00, 11.27it/s, loss=1.202]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:15,  1.45it/s]
# Epoch 25: train loss 1.2050 | val loss 2.6778 | val BLEU 23.15%
# Epoch 26/30: 100%|██████████████| 1589/1589 [02:21<00:00, 11.25it/s, loss=1.203]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:18,  1.42it/s]
# Epoch 26: train loss 1.1707 | val loss 2.7020 | val BLEU 22.54%
# Epoch 27/30: 100%|██████████████| 1589/1589 [02:20<00:00, 11.30it/s, loss=1.276]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:51,  1.76it/s]
# Epoch 27: train loss 1.1380 | val loss 2.7241 | val BLEU 23.22%
# Epoch 28/30: 100%|██████████████| 1589/1589 [02:21<00:00, 11.25it/s, loss=1.085]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:49,  1.79it/s]
# Epoch 28: train loss 1.1073 | val loss 2.7341 | val BLEU 23.05%
# Epoch 29/30: 100%|██████████████| 1589/1589 [02:20<00:00, 11.27it/s, loss=0.969]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:40,  1.22it/s]
# Epoch 29: train loss 1.0803 | val loss 2.7431 | val BLEU 23.00%
# Epoch 30/30: 100%|██████████████| 1589/1589 [02:22<00:00, 11.16it/s, loss=1.018]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:09,  1.52it/s]
# Epoch 30: train loss 1.0577 | val loss 2.7517 | val BLEU 23.02%
# 损失曲线图已保存至: results_ablation/4_heads_20251105_033423/loss_curve.png
#
# Evaluating best model on test set...
# Testing Loss: 100%|███████████████████████████| 199/199 [00:07<00:00, 27.81it/s]
# Test loss: 2.6678
#
# Calculating BLEU score on test set...
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:11,  1.49it/s]
# Test BLEU score: 22.29%
