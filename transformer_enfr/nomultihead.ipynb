# %% [markdown]
# #### 禁用多头

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 1 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --no_multihead --use_positional_encoding --use_residual --use_layernorm --use_decoder --experiment_name=single_head
# Out:
# 下载nltk必要数据...
# 训练结果将保存在: results_ablation/single_head_20251105_033936
# 使用设备: cuda
#
# 消融实验设置:
# 多头注意力: 禁用
# 位置编码: 启用
# 残差连接: 启用
# LayerNorm: 启用
# 解码器: 启用
#
# 构建数据集...
#
# 创建模型...
# 模型参数量: 19,333,664
#
# 开始训练...
# Epoch 1/30: 100%|███████████████| 1589/1589 [02:33<00:00, 10.34it/s, loss=4.087]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:00,  1.62it/s]
# Epoch 1: train loss 5.4757 | val loss 4.2993 | val BLEU 7.44%
#   保存新的最佳模型: val bleu = 7.44%
# Epoch 2/30: 100%|███████████████| 1589/1589 [02:32<00:00, 10.41it/s, loss=3.727]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:42,  1.91it/s]
# Epoch 2: train loss 3.9789 | val loss 3.5211 | val BLEU 10.91%
#   保存新的最佳模型: val bleu = 10.91%
# Epoch 3/30: 100%|███████████████| 1589/1589 [02:32<00:00, 10.43it/s, loss=3.225]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:42,  1.92it/s]
# Epoch 3: train loss 3.4038 | val loss 3.1905 | val BLEU 13.25%
#   保存新的最佳模型: val bleu = 13.25%
# Epoch 4/30: 100%|███████████████| 1589/1589 [02:32<00:00, 10.41it/s, loss=3.586]
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:38,  1.24it/s]
# Epoch 4: train loss 3.0583 | val loss 2.9588 | val BLEU 15.78%
#   保存新的最佳模型: val bleu = 15.78%
# Epoch 5/30: 100%|███████████████| 1589/1589 [02:34<00:00, 10.29it/s, loss=2.665]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:47,  1.82it/s]
# Epoch 5: train loss 2.7912 | val loss 2.8325 | val BLEU 16.80%
#   保存新的最佳模型: val bleu = 16.80%
# Epoch 6/30: 100%|███████████████| 1589/1589 [02:34<00:00, 10.27it/s, loss=2.683]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:53,  1.72it/s]
# Epoch 6: train loss 2.6047 | val loss 2.7592 | val BLEU 18.00%
#   保存新的最佳模型: val bleu = 18.00%
# Epoch 7/30: 100%|███████████████| 1589/1589 [02:36<00:00, 10.17it/s, loss=2.255]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:53,  1.72it/s]
# Epoch 7: train loss 2.4590 | val loss 2.7058 | val BLEU 17.78%
# Epoch 8/30: 100%|███████████████| 1589/1589 [02:36<00:00, 10.16it/s, loss=2.117]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:49,  1.79it/s]
# Epoch 8: train loss 2.3413 | val loss 2.6687 | val BLEU 18.84%
#   保存新的最佳模型: val bleu = 18.84%
# Epoch 9/30: 100%|███████████████| 1589/1589 [02:35<00:00, 10.23it/s, loss=2.146]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:45,  1.86it/s]
# Epoch 9: train loss 2.2409 | val loss 2.6432 | val BLEU 19.05%
#   保存新的最佳模型: val bleu = 19.05%
# Epoch 10/30:  38%|█████▋         | 596/1589 [00:57<01:38, 10.08it/s, loss=2.115]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Epoch 20/30: 100%|██████████████| 1589/1589 [02:34<00:00, 10.25it/s, loss=1.648]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:44,  1.88it/s]
# Epoch 20: train loss 1.5914 | val loss 2.6649 | val BLEU 21.96%
#   保存新的最佳模型: val bleu = 21.96%
# Epoch 21/30: 100%|██████████████| 1589/1589 [02:34<00:00, 10.26it/s, loss=1.706]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:54,  1.71it/s]
# Epoch 21: train loss 1.5496 | val loss 2.6637 | val BLEU 20.22%
# Epoch 22/30: 100%|██████████████| 1589/1589 [02:34<00:00, 10.30it/s, loss=1.832]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:10,  1.51it/s]
# Epoch 22: train loss 1.5112 | val loss 2.6724 | val BLEU 21.52%
# Epoch 23/30: 100%|██████████████| 1589/1589 [02:34<00:00, 10.27it/s, loss=1.462]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:52,  1.74it/s]
# Epoch 23: train loss 1.4741 | val loss 2.6912 | val BLEU 21.66%
# Epoch 24/30: 100%|██████████████| 1589/1589 [02:33<00:00, 10.35it/s, loss=1.380]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:49,  1.80it/s]
# Epoch 24: train loss 1.4396 | val loss 2.7034 | val BLEU 22.34%
#   保存新的最佳模型: val bleu = 22.34%
# Epoch 25/30: 100%|██████████████| 1589/1589 [02:35<00:00, 10.23it/s, loss=1.396]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:52,  1.74it/s]
# Epoch 25: train loss 1.4059 | val loss 2.7148 | val BLEU 21.65%
# Epoch 26/30: 100%|██████████████| 1589/1589 [02:36<00:00, 10.19it/s, loss=1.472]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:45,  1.86it/s]
# Epoch 26: train loss 1.3734 | val loss 2.7241 | val BLEU 21.46%
# Epoch 27/30: 100%|██████████████| 1589/1589 [02:36<00:00, 10.13it/s, loss=1.512]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:48,  1.81it/s]
# Epoch 27: train loss 1.3436 | val loss 2.7340 | val BLEU 21.99%
# Epoch 28/30: 100%|██████████████| 1589/1589 [02:34<00:00, 10.27it/s, loss=1.290]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:43,  1.89it/s]
# Epoch 28: train loss 1.3158 | val loss 2.7393 | val BLEU 21.97%
# Epoch 29/30: 100%|██████████████| 1589/1589 [02:33<00:00, 10.38it/s, loss=1.209]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:53,  1.73it/s]
# Epoch 29: train loss 1.2899 | val loss 2.7473 | val BLEU 21.89%
# Epoch 30/30: 100%|██████████████| 1589/1589 [02:34<00:00, 10.31it/s, loss=1.234]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:52,  1.74it/s]
# Epoch 30: train loss 1.2693 | val loss 2.7499 | val BLEU 22.23%
# 损失曲线图已保存至: results_ablation/single_head_20251105_033936/loss_curve.png
#
# Evaluating best model on test set...
# Testing Loss: 100%|███████████████████████████| 199/199 [00:07<00:00, 27.04it/s]
# Test loss: 2.7163
#
# Calculating BLEU score on test set...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:59,  1.63it/s]
# Test BLEU score: 21.01%
