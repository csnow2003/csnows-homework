# %% [markdown]
# 禁用位置编码

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 4 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --use_multihead --no_positional_encoding --use_residual --use_layernorm --use_decoder --experiment_name=no_positional_encoding
# Out:
# 训练结果将保存在: results_ablation/no_positional_encoding_20251105_050906
# 使用设备: cuda
#
# 消融实验设置:
# 多头注意力: 启用
# 位置编码: 禁用
# 残差连接: 启用
# LayerNorm: 启用
# 解码器: 启用
#
# 构建数据集...
#
# 创建模型...
# 模型参数量: 19,333,664
#
# 开始训练...
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:13,  1.47it/s]
# Epoch 1: train loss 5.5408 | val loss 4.5050 | val BLEU 4.43%
#   保存新的最佳模型: val bleu = 4.43%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:04,  1.58it/s]
# Epoch 2: train loss 4.2747 | val loss 3.9625 | val BLEU 6.80%
#   保存新的最佳模型: val bleu = 6.80%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:04,  1.58it/s]
# Epoch 3: train loss 3.8544 | val loss 3.7285 | val BLEU 7.91%
#   保存新的最佳模型: val bleu = 7.91%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:23,  1.36it/s]
# Epoch 4: train loss 3.5753 | val loss 3.5447 | val BLEU 7.92%
#   保存新的最佳模型: val bleu = 7.92%
# ...

# %%
禁用多头注意力

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 4 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --no_multihead --use_positional_encoding --use_residual --use_layernorm --use_decoder --experiment_name=no_multihead
# Out:
# 训练结果将保存在: results_ablation/no_multihead_20251105_063534
# 使用设备: cuda
#
# 消融实验设置:
# 多头注意力: 禁用
# 位置编码: 启用
# 残差连接: 启用
# LayerNorm: 启用
# 解码器: 启用
#
# 构建数据集...
#
# 创建模型...
# 模型参数量: 19,333,664
#
# 开始训练...
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:59,  1.64it/s]
#   保存新的最佳模型: val bleu = 6.81%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:37,  2.02it/s]
# Epoch 2: train loss 3.9803 | val loss 3.5240 | val BLEU 10.43%
#   保存新的最佳模型: val bleu = 10.43%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:47,  1.82it/s]
#   保存新的最佳模型: val bleu = 13.68%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:52,  1.74it/s]
# Epoch 4: train loss 3.0541 | val loss 2.9606 | val BLEU 15.36%
#   保存新的最佳模型: val bleu = 15.36%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:50,  1.77it/s]
#   保存新的最佳模型: val bleu = 17.68%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:01,  1.62it/s]
# ...

# %% [markdown]
# 禁用残差连接

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 4 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --use_multihead --use_positional_encoding --no_residual --use_layernorm --use_decoder --experiment_name=no_residual
# Out:
# 训练结果将保存在: results_ablation/no_residual_20251105_080107
# 使用设备: cuda
#
# 消融实验设置:
# 多头注意力: 启用
# 位置编码: 启用
# 残差连接: 禁用
# LayerNorm: 启用
# 解码器: 启用
#
# 构建数据集...
#
# 创建模型...
# 模型参数量: 19,333,664
#
# 开始训练...
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:54,  1.72it/s]
#   保存新的最佳模型: val bleu = 0.39%
# ...
# Calculating BLEU:   2%|▌                        | 4/199 [00:02<01:49,  1.79it/s]
# Epoch 2: train loss 6.0077 | val loss 6.0653 | val BLEU 0.37%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:52,  1.74it/s]
# Epoch 4: train loss 5.9612 | val loss 6.0663 | val BLEU 0.37%
# Epoch 5/30:  64%|█████████▋     | 1021/1589 [01:27<00:43, 12.98it/s, loss=5.941]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ...

# %% [markdown]
# 禁用LayerNorm

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 4 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --use_multihead --use_positional_encoding --use_residual --no_layernorm --use_decoder --experiment_name=no_layernorm
# Out:
# 训练结果将保存在: results_ablation/no_layernorm_20251105_091549
# 使用设备: cuda
#
# 消融实验设置:
# 多头注意力: 启用
# 位置编码: 启用
# 残差连接: 启用
# LayerNorm: 禁用
# 解码器: 启用
#
# 构建数据集...
#
# 创建模型...
# 模型参数量: 19,325,984
#
# 开始训练...
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:54,  1.72it/s]
#   保存新的最佳模型: val bleu = 6.93%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:49,  1.79it/s]
# Epoch 2: train loss 3.9886 | val loss 3.6114 | val BLEU 10.26%
#   保存新的最佳模型: val bleu = 10.26%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:50,  1.77it/s]
#   保存新的最佳模型: val bleu = 12.45%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<02:00,  1.63it/s]
# Epoch 4: train loss 3.1288 | val loss 3.0872 | val BLEU 14.63%
#   保存新的最佳模型: val bleu = 14.63%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:48,  1.80it/s]
#   保存新的最佳模型: val bleu = 16.51%
# ...
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:54,  1.71it/s]
# ...
