# %% [markdown]
# #### 4头

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 4 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --use_multihead --use_positional_encoding --use_residual --use_layernorm --use_decoder --experiment_name=4_heads
# Out:
# 训练结果将保存在: results_ablation/4_heads_20251105_033423
# 使用设备: cuda
#
# 消融实验设置:
# 多头注意力: 启用
# 位置编码: 启用
# 残差连接: 启用
# LayerNorm: 启用
# 解码器: 启用
#
# 构建数据集...
#
# 创建模型...
# 模型参数量: 19,333,664
#
# 开始训练...
# Epoch 1/30:  79%|███████████▉   | 1262/1589 [01:50<00:29, 11.18it/s, loss=4.635]

# %% [markdown]
# #### 8头

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 8 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --use_multihead --use_positional_encoding --use_residual --use_layernorm --use_decoder --experiment_name=8_heads

# %% [markdown]
# #### 禁用多头

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 1 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --no_multihead --use_positional_encoding --use_residual --use_layernorm --use_decoder --experiment_name=single_head

# %% [markdown]
# #### 16头

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 16 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --use_multihead --use_positional_encoding --use_residual --use_layernorm --use_decoder --experiment_name=16_heads
