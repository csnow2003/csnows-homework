# %% [markdown]
# #### 8头

# %%
# !python -m src.train_ablation --epochs 30 --batch_size 64 --lr 2e-4 --d_model 256 --nhead 8 --num_encoder_layers 3 --num_decoder_layers 3 --dim_feedforward 512 --dropout 0.1 --max_vocab 20000 --max_len 128 --use_multihead --use_positional_encoding --use_residual --use_layernorm --use_decoder --experiment_name=8_heads
# Out:
# 下载nltk必要数据...
# 训练结果将保存在: results_ablation/8_heads_20251105_034937
# 使用设备: cuda
#
# 消融实验设置:
# 多头注意力: 启用
# 位置编码: 启用
# 残差连接: 启用
# LayerNorm: 启用
# 解码器: 启用
#
# 构建数据集...
#
# 创建模型...
# 模型参数量: 19,333,664
#
# 开始训练...
# Epoch 1/30: 100%|███████████████| 1589/1589 [02:06<00:00, 12.51it/s, loss=4.056]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:51,  1.76it/s]
# Epoch 1: train loss 5.4730 | val loss 4.3085 | val BLEU 6.53%
#   保存新的最佳模型: val bleu = 6.53%
# Epoch 2/30: 100%|███████████████| 1589/1589 [02:05<00:00, 12.62it/s, loss=3.856]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:42,  1.91it/s]
# Epoch 2: train loss 3.9796 | val loss 3.5508 | val BLEU 10.95%
#   保存新的最佳模型: val bleu = 10.95%
# Epoch 3/30: 100%|███████████████| 1589/1589 [02:06<00:00, 12.57it/s, loss=3.242]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:48,  1.81it/s]
# Epoch 3: train loss 3.3542 | val loss 3.1200 | val BLEU 13.99%
#   保存新的最佳模型: val bleu = 13.99%
# Epoch 4/30: 100%|███████████████| 1589/1589 [02:06<00:00, 12.61it/s, loss=3.575]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:42,  1.92it/s]
# Epoch 4: train loss 2.9553 | val loss 2.8673 | val BLEU 16.38%
#   保存新的最佳模型: val bleu = 16.38%
# Epoch 5/30: 100%|███████████████| 1589/1589 [02:07<00:00, 12.51it/s, loss=2.468]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:40,  1.94it/s]
# Epoch 5: train loss 2.6654 | val loss 2.7259 | val BLEU 17.77%
#   保存新的最佳模型: val bleu = 17.77%
# Epoch 6/30: 100%|███████████████| 1589/1589 [02:06<00:00, 12.61it/s, loss=2.571]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:42,  1.91it/s]
# Epoch 6: train loss 2.4663 | val loss 2.6499 | val BLEU 17.49%
# Epoch 7/30:  61%|█████████▊      | 972/1589 [01:18<00:47, 12.91it/s, loss=2.389]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Epoch 20/30: 100%|██████████████| 1589/1589 [02:10<00:00, 12.22it/s, loss=1.374]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:41,  1.93it/s]
# Epoch 20: train loss 1.3832 | val loss 2.6262 | val BLEU 23.61%
# Epoch 21/30: 100%|██████████████| 1589/1589 [02:09<00:00, 12.23it/s, loss=1.511]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:56,  1.69it/s]
# Epoch 21: train loss 1.3388 | val loss 2.6446 | val BLEU 23.40%
# Epoch 22/30: 100%|██████████████| 1589/1589 [02:09<00:00, 12.30it/s, loss=1.595]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:46,  1.85it/s]
# Epoch 22: train loss 1.2953 | val loss 2.6626 | val BLEU 24.15%
# Epoch 23/30: 100%|██████████████| 1589/1589 [02:10<00:00, 12.16it/s, loss=1.164]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:42,  1.92it/s]
# Epoch 23: train loss 1.2542 | val loss 2.7002 | val BLEU 23.59%
# Epoch 24/30: 100%|██████████████| 1589/1589 [02:10<00:00, 12.16it/s, loss=1.195]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:50,  1.77it/s]
# Epoch 24: train loss 1.2150 | val loss 2.7163 | val BLEU 23.70%
# Epoch 25/30: 100%|██████████████| 1589/1589 [02:09<00:00, 12.25it/s, loss=1.191]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:47,  1.83it/s]
# Epoch 25: train loss 1.1769 | val loss 2.7378 | val BLEU 24.11%
# Epoch 26/30: 100%|██████████████| 1589/1589 [02:10<00:00, 12.13it/s, loss=1.212]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:41,  1.93it/s]
# Epoch 26: train loss 1.1415 | val loss 2.7568 | val BLEU 22.54%
# Epoch 27/30: 100%|██████████████| 1589/1589 [02:10<00:00, 12.22it/s, loss=1.231]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:46,  1.84it/s]
# Epoch 27: train loss 1.1082 | val loss 2.7858 | val BLEU 23.70%
# Epoch 28/30: 100%|██████████████| 1589/1589 [02:12<00:00, 12.01it/s, loss=1.123]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:41,  1.93it/s]
# Epoch 28: train loss 1.0761 | val loss 2.7925 | val BLEU 23.12%
# Epoch 29/30: 100%|██████████████| 1589/1589 [02:10<00:00, 12.15it/s, loss=0.984]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:42,  1.91it/s]
# Epoch 29: train loss 1.0492 | val loss 2.8064 | val BLEU 23.40%
# Epoch 30/30: 100%|██████████████| 1589/1589 [02:11<00:00, 12.11it/s, loss=0.998]
# Calculating BLEU:   2%|▍                        | 3/199 [00:01<01:45,  1.85it/s]
# Epoch 30: train loss 1.0262 | val loss 2.8138 | val BLEU 23.65%
# 损失曲线图已保存至: results_ablation/8_heads_20251105_034937/loss_curve.png
#
# Evaluating best model on test set...
# Testing Loss: 100%|███████████████████████████| 199/199 [00:06<00:00, 31.22it/s]
# Test loss: 2.6007
#
# Calculating BLEU score on test set...
# Calculating BLEU:   2%|▍                        | 3/199 [00:02<02:31,  1.29it/s]
# Test BLEU score: 21.65%
